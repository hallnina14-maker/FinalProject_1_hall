# %% [markdown]
# ### The climate model output can be retrieved via the same methods we worked through in unit5_models --- please refer back to that tutorial for working with CMIP6 data on Google Cloud Store and make the appropriate selection in the catalog to get your GFDL-ESM4 data that is required for the project.

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr  # to read in Zarr format
import gcsfs # to read google cloud data
import momlevel as ml
import cftime
import cmocean

# %%
xr.set_options(display_style='html')
# %matplotlib inline                           
# %config InlineBackend.figure_format='retina' 
plt.rcParams['figure.figsize'] = 12,6

# %%
google_cloud_cmip6 = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')

# %%
NCAR_store= google_cloud_cmip6[google_cloud_cmip6['institution_id']== "NCAR"]

# %%
NCAR_store
# Out:
#        activity_id institution_id source_id experiment_id member_id table_id  \
# 53442         CMIP           NCAR     CESM2          amip  r1i1p1f1     Amon
# 53443         CMIP           NCAR     CESM2          amip  r1i1p1f1     Amon
# 53444         CMIP           NCAR     CESM2          amip  r1i1p1f1     Amon
# 53445         CMIP           NCAR     CESM2          amip  r1i1p1f1       fx
# 53446         CMIP           NCAR     CESM2          amip  r1i1p1f1   AERmon
# ...            ...            ...       ...           ...       ...      ...
# 522974       C4MIP           NCAR     CESM2   1pctCO2-rad  r1i1p1f1     Amon
# 522975       C4MIP           NCAR     CESM2   1pctCO2-rad  r1i1p1f1     Amon
# 522976       C4MIP           NCAR     CESM2   1pctCO2-rad  r1i1p1f1     Emon
# 522977       C4MIP           NCAR     CESM2   1pctCO2-rad  r1i1p1f1     Amon
# 522978       C4MIP           NCAR     CESM2   1pctCO2-rad  r1i1p1f1     Amon
#
#        variable_id grid_label  \
# 53442         rlut         gn
# 53443         rlus         gn
# 53444         rlds         gn
# 53445       sftgif         gn
# 53446           ps         gn
# ...            ...        ...
# 522974        hurs         gn
# 522975         hus         gn
# 522976       mrsol         gn
# 522977          ps         gn
# 522978         tas         gn
#
#                                                    zstore  dcpp_init_year  \
# 53442   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r1i1p1f1...             NaN
# 53443   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r1i1p1f1...             NaN
# 53444   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r1i1p1f1...             NaN
# 53445   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r1i1p1f1...             NaN
# 53446   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r1i1p1f1...             NaN
# ...                                                   ...             ...
# 522974  gs://cmip6/CMIP6/C4MIP/NCAR/CESM2/1pctCO2-rad/...             NaN
# 522975  gs://cmip6/CMIP6/C4MIP/NCAR/CESM2/1pctCO2-rad/...             NaN
# 522976  gs://cmip6/CMIP6/C4MIP/NCAR/CESM2/1pctCO2-rad/...             NaN
# 522977  gs://cmip6/CMIP6/C4MIP/NCAR/CESM2/1pctCO2-rad/...             NaN
# 522978  gs://cmip6/CMIP6/C4MIP/NCAR/CESM2/1pctCO2-rad/...             NaN
#
#          version
# 53442   20190218
# 53443   20190218
# 53444   20190218
# 53445   20190218
# 53446   20190218
# ...          ...
# 522974  20210816
# 522975  20210816
# 522976  20210816
# 522977  20210816
# 522978  20210816
#
# [123799 rows x 11 columns]

# %%
NCAR_TAS = NCAR_store[NCAR_store['variable_id'] == "tas"]

# %%
NCAR_TAS[NCAR_TAS['table_id'] == 'Amon']
# Out:
#         activity_id institution_id       source_id   experiment_id  member_id  \
# 53470          CMIP           NCAR           CESM2            amip   r1i1p1f1
# 55152          CMIP           NCAR     CESM2-WACCM            amip   r1i1p1f1
# 55166          CMIP           NCAR           CESM2            amip   r3i1p1f1
# 55213          CMIP           NCAR     CESM2-WACCM            amip   r3i1p1f1
# 55264          CMIP           NCAR           CESM2            amip   r2i1p1f1
# ...             ...            ...             ...             ...        ...
# 495600        PAMIP           NCAR  CESM1-WACCM-SC     piSST-pdSIC  r98i1p1f1
# 495604        PAMIP           NCAR  CESM1-WACCM-SC  pdSST-piAntSIC  r88i1p1f1
# 495610        PAMIP           NCAR  CESM1-WACCM-SC  pdSST-piAntSIC  r89i1p1f1
# 514502  ScenarioMIP           NCAR     CESM2-WACCM          ssp126   r1i1p1f1
# 522978        C4MIP           NCAR           CESM2     1pctCO2-rad   r1i1p1f1
#
#        table_id variable_id grid_label  \
# 53470      Amon         tas         gn
# 55152      Amon         tas         gn
# 55166      Amon         tas         gn
# 55213      Amon         tas         gn
# 55264      Amon         tas         gn
# ...         ...         ...        ...
# 495600     Amon         tas         gn
# 495604     Amon         tas         gn
# 495610     Amon         tas         gn
# 514502     Amon         tas         gn
# 522978     Amon         tas         gn
#
#                                                    zstore  dcpp_init_year  \
# 53470   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r1i1p1f1...             NaN
# 55152   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/amip/r1...             NaN
# 55166   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r3i1p1f1...             NaN
# 55213   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/amip/r3...             NaN
# 55264   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/amip/r2i1p1f1...             NaN
# ...                                                   ...             ...
# 495600  gs://cmip6/CMIP6/PAMIP/NCAR/CESM1-WACCM-SC/piS...             NaN
# 495604  gs://cmip6/CMIP6/PAMIP/NCAR/CESM1-WACCM-SC/pdS...             NaN
# 495610  gs://cmip6/CMIP6/PAMIP/NCAR/CESM1-WACCM-SC/pdS...             NaN
# 514502  gs://cmip6/CMIP6/ScenarioMIP/NCAR/CESM2-WACCM/...             NaN
# 522978  gs://cmip6/CMIP6/C4MIP/NCAR/CESM2/1pctCO2-rad/...             NaN
#
#          version
# 53470   20190218
# 55152   20190220
# 55166   20190220
# 55213   20190220
# 55264   20190220
# ...          ...
# 495600  20201012
# 495604  20201012
# 495610  20201012
# 514502  20210211
# 522978  20210816
#
# [5758 rows x 11 columns]

# %%
gfdl_esm4_thetao_data = google_cloud_cmip6.query(
    "activity_id=='CMIP' & \
    table_id == 'Amon' & \
    variable_id == 'tas' & \
    experiment_id == 'ssp585' & \
    institution_id == 'NCAR' &  \
    source_id == 'CESM2-FV2' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)
